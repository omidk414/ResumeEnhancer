# %% [markdown]
# # Job Scraping and Data Processing
#
# This notebook demonstrates how to scrape job listings from SimplyHired using Selenium, and how to merge and clean the resulting CSV files. The final output is a single merged dataset containing job information like job title, company name, location, estimated salary, job details, and job links.
#
# ## Sections:
# 1. Scrape job listings for specific roles.
# 2. Merge scraped data from multiple CSV files.
# 3. Standardize column names and handle missing data.

# %% [markdown]
# ## Scrape Job Listings
#
# The `scrape_jobs` function performs web scraping on the SimplyHired website. Given a job title and location, it:
# - Constructs the URL.
# - Collects job titles, company names, locations, estimated salaries, job details, and job links.
# - Handles pagination and error logging.
# - Saves the data as a CSV file named based on the job title and location.
#
# **Key Features:**
# - Scrapes job listings using Selenium.
# - Handles multiple pages and collects job details from each job link.
# - Logs errors to a file (`web_scraping_errors.log`) to help with debugging.

# %%
import pandas as pd

def scrape_jobs(job_title, location):
    from selenium import webdriver
    from selenium.webdriver.common.by import By
    import time
    from selenium.common.exceptions import NoSuchElementException
    import logging

    # Set up logging to capture errors
    logging.basicConfig(filename='web_scraping_errors.log', level=logging.ERROR)

    # Create a Chrome browser instance
    driver = webdriver.Chrome()

    # Construct the URL
    url = f"https://www.simplyhired.com/search?q={job_title}&l={location}"

    # Initialize data lists
    job_titles, company_names, job_locations, est_salary, job_details, job_hrefs = [], [], [], [], [], []

    total_job_count = 0

    try:
        # Visit the URL
        driver.get(url)

        while True:
            # Extract the total job count from the element
            total_job_element = driver.find_element(By.CSS_SELECTOR, "p.css-gu0het")
            total_job_count = int(total_job_element.text)

            # Find all job title elements and corresponding company name elements on the current page
            job_title_elements = driver.find_elements(By.CSS_SELECTOR, "[data-testid='searchSerpJobTitle'] a")
            company_name_elements = driver.find_elements(By.CSS_SELECTOR, "[data-testid='companyName']")
            job_location_elements = driver.find_elements(By.CSS_SELECTOR, "[data-testid='searchSerpJobLocation']")
            est_salary_elements = driver.find_elements(By.CSS_SELECTOR, "[data-testid='searchSerpJobSalaryEst']")
            job_href_elements = driver.find_elements(By.CSS_SELECTOR, "[data-testid='searchSerpJobTitle'] a")

            # Iterate through the job elements to extract job titles, company names, and href links
            for job_title_element, company_name_element, job_location_element, est_salary_element, job_href_element in zip(job_title_elements, company_name_elements, job_location_elements, est_salary_elements, job_href_elements):
                job_titles.append(job_title_element.text)
                company_names.append(company_name_element.text)
                job_locations.append(job_location_element.text)
                est_salary.append(est_salary_element.text)

                # Click on the job href to get details and open in a new window
                job_href = job_href_element.get_attribute("href")
                job_hrefs.append(job_href)  # Store the href link
                driver.execute_script("window.open('', '_blank');")
                driver.switch_to.window(driver.window_handles[1])
                driver.get(job_href)

                try:
                    job_detail_element = driver.find_element(By.CSS_SELECTOR, "[data-testid='viewJobBodyJobFullDescriptionContent']")
                    job_details.append(job_detail_element.text)
                except NoSuchElementException:
                    job_details.append("N/A")

                driver.close()  # Close the job details tab
                driver.switch_to.window(driver.window_handles[0])  # Switch back to the job listing tab

            # Find the next page button
            next_page_button = driver.find_element(By.XPATH, "//a[@aria-label='Next page']")

            # Scroll to the next page button to make it clickable
            driver.execute_script("arguments[0].scrollIntoView();", next_page_button)

            # Click the next page button
            next_page_button.click()

            # Wait for a short period before loading the next page
            time.sleep(5)  # Wait for 5 seconds

            # Break the loop if we have collected data from all pages
            if len(job_titles) >= total_job_count:
                break

    except NoSuchElementException as e:
        # Handle the specific exception (element not found)
        logging.error(f"Element not found error: {str(e)}")
    except Exception as e:
        # Handle other exceptions and log them
        logging.error(f"An error occurred: {str(e)}")

    finally:
        # Close the browser when done
        driver.quit()

    # Create a dictionary to store the data
    data = {
        'Job Title': job_titles,
        'Company Name': company_names,
        'Job Location': job_locations,
        'Estimated Salary': est_salary,
        'Job details': job_details,
        'Job Href': job_hrefs  # Include the href links
    }

    # Check if all lists have the same length
    lengths = set(len(lst) for lst in data.values())
    if len(lengths) == 1:
        # All lists have the same length, create the DataFrame
        df = pd.DataFrame(data)
    else:
        # Lists have different lengths, handle the error
        print("Error: Lists have different lengths")
        df = None  # Set df to None or handle the error as needed

    # Save the data to a CSV file if the DataFrame is not None
    if df is not None:
        file_name = f'{job_title}_{location}_{time.strftime("%Y-%m-%d")}.csv'
        df.to_csv(file_name, index=False)

    # Return the DataFrame (or None)
    return df

# %% [markdown]
# ## Scraping Data for Different Job Roles
#
# Here we demonstrate scraping job listings for different roles such as Data Engineer, Software Engineer, and Data Scientist. Each search result is saved into a separate CSV file.
#
# For example:
# - **Data Engineer** jobs in California.
# - **Software Engineer** jobs in California.
# - **Data Scientist** jobs in California.

# %%
data_engineer = scrape_jobs("Data Engineer", "California")
data_engineer
# Out:
#                                              Job Title  \
# 0           Senior Network Engineer - RRMS Data Center
# 1                                        Data Engineer
# 2             Data Engineer, Real Estate and Workplace
# 3                     Principal Data Modeling Engineer
# 4                 Lead Data Engineer, Data and Systems
# ..                                                 ...
# 251  Application Engineer II - Data Management (Min...
# 252         Senior Network Engineer - RRMS Data Center
# 253                             Data Platform Engineer
# 254  Cellular 4G/5G Firmware Data Science & Machine...
# 255        Senior Data Center Test Automation Engineer
#
#                                       Company Name       Job Location  \
# 0                        Rapid Response Monitoring         Corona, CA
# 1    RECRUIT ROOTS GLOBAL SERVICES PRIVATE LIMITED       Glendale, CA
# 2                                           OpenAI  San Francisco, CA
# 3                                           Oracle     Pleasanton, CA
# 4                                        Pendulum™  San Francisco, CA
# ..                                             ...                ...
# 251                                          Ansys      San Diego, CA
# 252                      Rapid Response Monitoring         Corona, CA
# 253                                         Joyent  Mountain View, CA
# 254                                          Apple      Sunnyvale, CA
# 255                                         NVIDIA    Santa Clara, CA
#
#                      Estimated Salary  \
# 0     Estimated: $150K - $190K a year
# 1     Estimated: $151K - $191K a year
# 2    Estimated: $88.7K - $112K a year
# 3     Estimated: $173K - $218K a year
# 4     Estimated: $118K - $149K a year
# ..                                ...
# 251   Estimated: $116K - $147K a year
# 252   Estimated: $113K - $143K a year
# 253   Estimated: $150K - $190K a year
# 254   Estimated: $114K - $144K a year
# 255   Estimated: $102K - $129K a year
#
#                                            Job details  \
# 0    Location\nThis position is 100% in-office and ...
# 1    Job Title: Sr Data Engineer\nLocation: Glendal...
# 2    About the Team\nOpenAI has a beautiful, custom...
# 3    This position is onsite/hybrid in our Pleasant...
# 4    About Pendulum\nPendulum® is leading a revolut...
# ..                                                 ...
# 251  Requisition #: 14831\n\nOur Mission: Powering ...
# 252  Location\nThis position is 100% in-office and ...
# 253  Mountain View, CA, Hybrid (3 times per week)\n...
# 254  Summary\n\nPosted: Jul 25, 2024\n\nRole Number...
# 255  NVIDIA’s invention of the GPU in 1999 sparked ...
#
#                                               Job Href
# 0    https://www.simplyhired.com/job/CXnvktX5Idn-qe...
# 1    https://www.simplyhired.com/job/L8wcbSMF2gGGbM...
# 2    https://www.simplyhired.com/job/gSntIEgdlm-bZW...
# 3    https://www.simplyhired.com/job/5yV0h_UhLlnrYk...
# 4    https://www.simplyhired.com/job/2SJyt_v7FSdSA8...
# ..                                                 ...
# 251  https://www.simplyhired.com/job/KDvCkdU6RSLBMr...
# 252  https://www.simplyhired.com/job/CXnvktX5Idn-qe...
# 253  https://www.simplyhired.com/job/47Ex9cyS9zJSmA...
# 254  https://www.simplyhired.com/job/gMY9aLS1SsD1bC...
# 255  https://www.simplyhired.com/job/lpP-GRmXvuFw6I...
#
# [256 rows x 6 columns]

# %%
Software_engineer = scrape_jobs("Software Engineer", "California")
Software_engineer
# Out:
#                                              Job Title  \
# 0                      Landing Page Developer/Designer
# 1    WordPress Developer (Front-end design & robust...
# 2    Sr. Principal Engineer Software - Simulation (...
# 3                           AS400 EDI & RPG Specialist
# 4           Sr. Principal Software Engineer - Database
# ..                                                 ...
# 862                     Controls / Automation Engineer
# 863                     Visualization Engineer (Unity)
# 864                           Senior Software Engineer
# 865  Principal Software Engineer, ADAS Compute Plat...
# 866                          Backend Software Engineer
#
#                        Company Name          Job Location  \
# 0                      Confidential       Los Angeles, CA
# 1                      Rhodes Wolfe      Palm Springs, CA
# 2                  Northrop Grumman          Palmdale, CA
# 3    Amphastar Pharmaceuticals Inc.  Rancho Cucamonga, CA
# 4                  Northrop Grumman         Camarillo, CA
# ..                              ...                   ...
# 862                        Actalent         San Diego, CA
# 863                        Dynamoid           Oakland, CA
# 864        Software Resources, Inc.          Glendale, CA
# 865                  General Motors     Mountain View, CA
# 866                     CyberCoders       Los Angeles, CA
#
#                      Estimated Salary  \
# 0     Estimated: $137K - $174K a year
# 1     Estimated: $103K - $130K a year
# 2     Estimated: $113K - $144K a year
# 3     Estimated: $119K - $151K a year
# 4     Estimated: $170K - $215K a year
# ..                                ...
# 862   Estimated: $119K - $151K a year
# 863   Estimated: $168K - $213K a year
# 864  Estimated: $95.5K - $121K a year
# 865   Estimated: $138K - $174K a year
# 866   Estimated: $142K - $180K a year
#
#                                            Job details  \
# 0    Description:\nThis is an in house position wit...
# 1    WordPress Developer (Web Design & Website Mana...
# 2    Requisition ID: R10160394\nCategory: Engineeri...
# 3    A Pharmaceutical Manufacturing company is look...
# 4    Requisition ID: R10167691\nCategory: Engineeri...
# ..                                                 ...
# 862  Title: Automation / Controls Engineer\nPositio...
# 863  We are a small, growing team and value those w...
# 864  Software Resources has an immediate job opport...
# 865  Job Description\nIf you are a Principal S oftw...
# 866  Backend Software Engineer\nAre you a Backend S...
#
#                                               Job Href
# 0    https://www.simplyhired.com/job/NUmNZU3i-XDtMe...
# 1    https://www.simplyhired.com/job/D2a3iro1uKJEJg...
# 2    https://www.simplyhired.com/job/adtBmo2BSL-nII...
# 3    https://www.simplyhired.com/job/mX2hi4lFGqhiNd...
# 4    https://www.simplyhired.com/job/cQSQ4F8Kx55j5v...
# ..                                                 ...
# 862  https://www.simplyhired.com/job/m5Cu7OhrOQo4F2...
# 863  https://www.simplyhired.com/job/3l4J36FPhNXjuH...
# 864  https://www.simplyhired.com/job/WtDmSvYZ7VXE4U...
# 865  https://www.simplyhired.com/job/dhRW87m04ODLaV...
# 866  https://www.simplyhired.com/job/a_9Z5ieMinj1Gv...
#
# [867 rows x 6 columns]

# %%
Data_Scientist = scrape_jobs("Data Scientist", "California")
Data_Scientist
# Out:
#                                              Job Title  \
# 0                               Sr. Data Analyst (SQL)
# 1           Medicine - Artificial Intelligence Faculty
# 2    Sr. WW Specialist, GenAI, Model Training & Inf...
# 3                Senior Data Scientist, AI Foundations
# 4          AI Models Engineer, Efficient Generative AI
# ..                                                 ...
# 174         Medicine - Artificial Intelligence Faculty
# 175  Forensics - Discovery Data Scientist - Manager...
# 176             Machine Learning Lead - Drug Discovery
# 177         Medicine - Artificial Intelligence Faculty
# 178                   Data Scientist (updated 6-11-24)
#
#                               Company Name                Job Location  \
# 0                  MOBIS PARTS AMERICA LLC         Fountain Valley, CA
# 1                             CEDARS-SINAI             Los Angeles, CA
# 2          Amazon Web Services, Inc. - A97             Santa Clara, CA
# 3                              Capital One           San Francisco, CA
# 4              Advanced Micro Devices, Inc                San Jose, CA
# ..                                     ...                         ...
# 174                           CEDARS-SINAI             Los Angeles, CA
# 175                                     EY           San Francisco, CA
# 176                 Vertex Pharmaceuticals               San Diego, CA
# 177                           CEDARS-SINAI             Los Angeles, CA
# 178  Lawrence Berkeley National Laboratory  San Francisco Bay Area, CA
#
#                       Estimated Salary  \
# 0      Estimated: $159K - $201K a year
# 1     Estimated: $99.3K - $126K a year
# 2      Estimated: $152K - $192K a year
# 3      Estimated: $120K - $152K a year
# 4      Estimated: $165K - $210K a year
# ..                                 ...
# 174    Estimated: $159K - $201K a year
# 175    Estimated: $142K - $180K a year
# 176    Estimated: $169K - $214K a year
# 177  Estimated: $69.8K - $88.4K a year
# 178    Estimated: $157K - $199K a year
#
#                                            Job details  \
# 0    ****Interested applicants must reside in South...
# 1    The Division of Artificial Intelligence in Med...
# 2    Are you a customer-obsessed builder with a pas...
# 3    Center 2 (19050), United States of America, Mc...
# 4    Overview:\nWHAT YOU DO AT AMD CHANGES EVERYTHI...
# ..                                                 ...
# 174  The Division of Artificial Intelligence in Med...
# 175  At EY, you’ll have the chance to build a caree...
# 176  Job Description\nVertex Pharmaceuticals is see...
# 177  The Division of Artificial Intelligence in Med...
# 178  The Berkeley Lab is seeking a Data Scientist (...
#
#                                               Job Href
# 0    https://www.simplyhired.com/job/WXIOxG-Z-lU17v...
# 1    https://www.simplyhired.com/job/_t1HoPxcMcxPUC...
# 2    https://www.simplyhired.com/job/AoiOKM4p3NAK7V...
# 3    https://www.simplyhired.com/job/MPrBjKlXrmVzLl...
# 4    https://www.simplyhired.com/job/93vfawT-eCyU9v...
# ..                                                 ...
# 174  https://www.simplyhired.com/job/_t1HoPxcMcxPUC...
# 175  https://www.simplyhired.com/job/knH1yTbFl2eDWy...
# 176  https://www.simplyhired.com/job/tZ74-gbXNPt6rA...
# 177  https://www.simplyhired.com/job/_t1HoPxcMcxPUC...
# 178  https://www.simplyhired.com/job/OAHjrc-vQKTYnX...
#
# [179 rows x 6 columns]

# %%
Data_Analyst = scrape_jobs("Data Analyst", "California")
Data_Analyst
# Out:
#                                              Job Title  \
# 0                               Lab Analyst - C4I WISE
# 1    Healthcare Data Analyst II-Health Services Eva...
# 2    Laboratory Data and Inspection Analyst (Associ...
# 3                                      IT Data Analyst
# 4    Board Certified Behavioral Analyst- San Diego ...
# ..                                                 ...
# 160                      Provider Compensation Analyst
# 161                                 Business Analyst 4
# 162                             Lab Analyst - C4I WISE
# 163  Healthcare Data Analyst II-Health Services Eva...
# 164                                       Data Analyst
#
#                                       Company Name          Job Location  \
# 0                                  F2 Systems, LLC    Camp Pendleton, CA
# 1                        Inland Empire Health Plan  Rancho Cucamonga, CA
# 2    California Department of Public Health (CDPH)       Los Angeles, CA
# 3       California Commercial Investment Group Inc        Sacramento, CA
# 4                      Redwood Family Care Network         San Diego, CA
# ..                                             ...                   ...
# 160                            Medica Talent Group       Los Angeles, CA
# 161                                    Ursus, Inc.     San Francisco, CA
# 162                                F2 Systems, LLC    Camp Pendleton, CA
# 163                      Inland Empire Health Plan  Rancho Cucamonga, CA
# 164                Yoh, A Day & Zimmermann Company     Mountain View, CA
#
#                       Estimated Salary  \
# 0     Estimated: $99.3K - $126K a year
# 1     Estimated: $80.9K - $102K a year
# 2    Estimated: $62.1K - $78.6K a year
# 3      Estimated: $103K - $131K a year
# 4      Estimated: $103K - $130K a year
# ..                                 ...
# 160    Estimated: $103K - $131K a year
# 161    Estimated: $73.4K - $93K a year
# 162   Estimated: $99.3K - $126K a year
# 163   Estimated: $80.9K - $102K a year
# 164  Estimated: $62.1K - $78.6K a year
#
#                                            Job details  \
# 0    ACTIVE DOD CLEARANCE REQUIRED\nPosition Title:...
# 1    What You Can You Expect!\n\nFind joy in servin...
# 2    The California Department of Public Health (CD...
# 3    We make good investments in our people, proper...
# 4    Board Certified Behavioral Analyst- San Diego ...
# ..                                                 ...
# 160  Location: HYBRID (3 days onsite Commerce, CA +...
# 161  JOB TITLE: Business Analyst 4\nLOCATION: 100% ...
# 162  ACTIVE DOD CLEARANCE REQUIRED\nPosition Title:...
# 163  What You Can You Expect!\n\nFind joy in servin...
# 164  Looking for a Data Analyst to support optimiza...
#
#                                               Job Href
# 0    https://www.simplyhired.com/job/wGUNJXVxNE1ZCn...
# 1    https://www.simplyhired.com/job/xLjvAZ5FKMLmEU...
# 2    https://www.simplyhired.com/job/3YhmQ1PfVoNANc...
# 3    https://www.simplyhired.com/job/8hk-ERsohqWOvA...
# 4    https://www.simplyhired.com/job/HYrAqWgEFCFNqx...
# ..                                                 ...
# 160  https://www.simplyhired.com/job/5dSSskqDxf3roS...
# 161  https://www.simplyhired.com/job/cCQ5-XUdEJtm7Q...
# 162  https://www.simplyhired.com/job/wGUNJXVxNE1ZCn...
# 163  https://www.simplyhired.com/job/xLjvAZ5FKMLmEU...
# 164  https://www.simplyhired.com/job/dzkET6d86Jr3T_...
#
# [165 rows x 6 columns]

# %%
Business_Systems_Analyst = scrape_jobs("Business Systems Analyst", "California")
Business_Systems_Analyst
# Out:
# Error: Lists have different lengths

# %%
Software_Developer = scrape_jobs("Software_Developer", "California")
Software_Developer
# Out:
#                                              Job Title  \
# 0                      BIM Manager / Architecture Firm
# 1                                        IT Specialist
# 2    Senior Software Developer – Compute Platform S...
# 3                                Jr Software Developer
# 4    Senior Software Developer in Test / Aerospace ...
# ..                                                 ...
# 235                     SMTS Software Development Eng.
# 236   Software Developer in Test - Embedded Sensors QE
# 237  Software Dev Engineer II, Last Mile Routing Pl...
# 238                                  Software Engineer
# 239                         Systems Software Developer
#
#                     Company Name         Job Location  \
# 0                     Tegrastaff    San Francisco, CA
# 1            Primus Auditing Ops      Santa Maria, CA
# 2                 General Motors    Mountain View, CA
# 3                   Alutiiq, LLC        San Diego, CA
# 4             Motion Recruitment       El Segundo, CA
# ..                           ...                  ...
# 235  Advanced Micro Devices, Inc      Santa Clara, CA
# 236                        Apple        Cupertino, CA
# 237      Amazon.com Services LLC  San Luis Obispo, CA
# 238    Harbor Truck Bodies, Inc.          Fontana, CA
# 239                        Apple        Sunnyvale, CA
#
#                      Estimated Salary  \
# 0     Estimated: $115K - $146K a year
# 1     Estimated: $141K - $178K a year
# 2     Estimated: $149K - $188K a year
# 3     Estimated: $150K - $189K a year
# 4    Estimated: $89.9K - $114K a year
# ..                                ...
# 235  Estimated: $89.9K - $114K a year
# 236   Estimated: $166K - $210K a year
# 237   Estimated: $183K - $231K a year
# 238   Estimated: $151K - $192K a year
# 239   Estimated: $135K - $171K a year
#
#                                            Job details  \
# 0    BIM MANAGER (SAN FRANCISCO)\nWe are looking fo...
# 1    GENERAL DESCRIPTION\nSoftware developer: Creat...
# 2    Job Description\nThe Software Defined Vehicle ...
# 3    Job Description:\n\nAlutiiq Career Ventures, L...
# 4    Job Description A SaaS company that builds pla...
# ..                                                 ...
# 235  Overview:\nWHAT YOU DO AT AMD CHANGES EVERYTHI...
# 236  Summary\n\nPosted: Sep 8, 2024\n\nWeekly Hours...
# 237  3+ years of non-internship professional softwa...
# 238  Position: Software Developer & Reporting Engin...
# 239  Summary\n\nPosted: Aug 12, 2024\n\nRole Number...
#
#                                               Job Href
# 0    https://www.simplyhired.com/job/wBmJcA0LKa1OMQ...
# 1    https://www.simplyhired.com/job/4m9PvrpIq_oD_F...
# 2    https://www.simplyhired.com/job/bzWI8Tjg_4q9Jp...
# 3    https://www.simplyhired.com/job/FOC_fVn2W9pd8Y...
# 4    https://www.simplyhired.com/job/EvURDeb00H9Khp...
# ..                                                 ...
# 235  https://www.simplyhired.com/job/dsxAmCj8o8Gwsd...
# 236  https://www.simplyhired.com/job/iuznYATd2x2pCo...
# 237  https://www.simplyhired.com/job/z-hyo3rMavkhsV...
# 238  https://www.simplyhired.com/job/MOYjZllMfjAbWS...
# 239  https://www.simplyhired.com/job/9Z2Cs-fLZRWLE3...
#
# [240 rows x 6 columns]

# %% [markdown]
# # Mapping the column names in all the csv files and merge csv files

# %% [markdown]
# ## Merging CSV Files
#
# After scraping multiple job roles, the data is stored in separate CSV files. In this section, we:
# - Load all CSV files from the `data/` folder.
# - Standardize the column names to maintain consistency across different datasets.
# - Merge all CSV files into a single DataFrame.
#
# **Column Mapping:**
# We use a dictionary to map inconsistent column names (like `Job Title`, `Company`, `Location`) to standardized names (`Job_Title`, `Company_Name`, `Job_Location`, etc.).

# %% [markdown]
# ## Standardize and Merge Data
#
# In this step:
# - All columns in the CSV files are renamed according to the `column_name_mapping`.
# - The data is concatenated into a single DataFrame, ensuring that all records have a uniform structure.
# - The resulting DataFrame contains columns like `Job_Title`, `Company_Name`, `Job_Location`, `Estimated_Salary`, `Job_Details`, and `Hyperlink`.

# %%
import os 
# Define the path to the folder containing CSV files
folder_path = 'data/'

# Get a list of all CSV files in the folder
file_paths = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.csv')]

# Define a dictionary to map old column names to new column names
column_name_mapping = {
    'Job Title': 'Job_Title',
    'Company Name': 'Company_Name',
    'Company' : 'Company_Name',
    'Location': 'Job_Location',
    'Job Location': 'Job_Location',
    'Salary': 'Estimated_Salary',
    'Estimated Salary': 'Estimated_Salary',
    'Href': 'Hyperlink',
    'Job Href': 'Hyperlink',
    'Job Description': 'Job_Details',
    'Job details': 'Job_Details'
}

# Read all CSV files into DataFrames and rename columns
dataframes = []

for file_path in file_paths:
    df = pd.read_csv(file_path)
    df.rename(columns=column_name_mapping, inplace=True)
    dataframes.append(df)

# Concatenate the DataFrames row-wise
merged_df = pd.concat(dataframes, ignore_index=True)

# Define the desired column order
desired_columns = [
    'Job_Title',
    'Company_Name',
    'Job_Location',
    'Estimated_Salary',
    'Job_Details',
    'Hyperlink',
]

# Reorder columns to match the desired order
merged_df = merged_df[desired_columns]

# Save the merged DataFrame to a CSV file
merged_df.to_csv('merged_file.csv', index=False)

# %% [markdown]
# ## Final Merged DataFrame
#
# The merged dataset contains all the scraped job listings across different job roles. Below, we display a preview of the first few rows of the combined dataset.
#
# You can save this final DataFrame to a CSV file for further analysis.

# %%
merged_df
# Out:
#                                               Job_Title  \
# 0                                Lab Analyst - C4I WISE
# 1     Healthcare Data Analyst II-Health Services Eva...
# 2     Laboratory Data and Inspection Analyst (Associ...
# 3                                       IT Data Analyst
# 4     Board Certified Behavioral Analyst- San Diego ...
# ...                                                 ...
# 1462                     Controls / Automation Engineer
# 1463                     Visualization Engineer (Unity)
# 1464                           Senior Software Engineer
# 1465  Principal Software Engineer, ADAS Compute Plat...
# 1466                          Backend Software Engineer
#
#                                        Company_Name          Job_Location  \
# 0                                   F2 Systems, LLC    Camp Pendleton, CA
# 1                         Inland Empire Health Plan  Rancho Cucamonga, CA
# 2     California Department of Public Health (CDPH)       Los Angeles, CA
# 3        California Commercial Investment Group Inc        Sacramento, CA
# 4                       Redwood Family Care Network         San Diego, CA
# ...                                             ...                   ...
# 1462                                       Actalent         San Diego, CA
# 1463                                       Dynamoid           Oakland, CA
# 1464                       Software Resources, Inc.          Glendale, CA
# 1465                                 General Motors     Mountain View, CA
# 1466                                    CyberCoders       Los Angeles, CA
#
#                        Estimated_Salary  \
# 0      Estimated: $99.3K - $126K a year
# 1      Estimated: $80.9K - $102K a year
# 2     Estimated: $62.1K - $78.6K a year
# 3       Estimated: $103K - $131K a year
# 4       Estimated: $103K - $130K a year
# ...                                 ...
# 1462    Estimated: $119K - $151K a year
# 1463    Estimated: $168K - $213K a year
# 1464   Estimated: $95.5K - $121K a year
# 1465    Estimated: $138K - $174K a year
# 1466    Estimated: $142K - $180K a year
#
#                                             Job_Details  \
# 0     ACTIVE DOD CLEARANCE REQUIRED\nPosition Title:...
# 1     What You Can You Expect!\n\nFind joy in servin...
# 2     The California Department of Public Health (CD...
# 3     We make good investments in our people, proper...
# 4     Board Certified Behavioral Analyst- San Diego ...
# ...                                                 ...
# 1462  Title: Automation / Controls Engineer\nPositio...
# 1463  We are a small, growing team and value those w...
# 1464  Software Resources has an immediate job opport...
# 1465  Job Description\nIf you are a Principal S oftw...
# 1466  Backend Software Engineer\nAre you a Backend S...
#
#                                               Hyperlink
# 0     https://www.simplyhired.com/job/wGUNJXVxNE1ZCn...
# 1     https://www.simplyhired.com/job/xLjvAZ5FKMLmEU...
# 2     https://www.simplyhired.com/job/3YhmQ1PfVoNANc...
# 3     https://www.simplyhired.com/job/8hk-ERsohqWOvA...
# 4     https://www.simplyhired.com/job/HYrAqWgEFCFNqx...
# ...                                                 ...
# 1462  https://www.simplyhired.com/job/m5Cu7OhrOQo4F2...
# 1463  https://www.simplyhired.com/job/3l4J36FPhNXjuH...
# 1464  https://www.simplyhired.com/job/WtDmSvYZ7VXE4U...
# 1465  https://www.simplyhired.com/job/dhRW87m04ODLaV...
# 1466  https://www.simplyhired.com/job/a_9Z5ieMinj1Gv...
#
# [1467 rows x 6 columns]

# %%
merged_df['Job_Title'][0]
# Out:
# 'Lab Analyst - C4I WISE'

# %%
merged_df.Job_Details.isna().sum()
# Out:
# 0
